# %%
import pandas as pd
ds = pd.read_csv("/Users/qdai/Documents/practice_machine_learning/linear regression/Salary.csv")
ds.shape
# Out:
# (35, 2)

# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

# %%
# %matplotlib inline
plt.xlabel('Years')
plt.ylabel('US dollors($)')
plt.scatter(ds.YearsExperience, ds.Salary, marker= '+')

# %%
reg = linear_model.LinearRegression()
reg.fit(ds[['YearsExperience']], ds.Salary)
intercept = reg.intercept_
print(intercept)
slope = reg.coef_
print(slope)

line = slope*ds.YearsExperience+intercept
plt.plot(ds.YearsExperience,ds.Salary,'o', ds.YearsExperience, line)
# Out:
# 28859.526194531463
# [8731.94104706]
# ...

# %%
scores = cross_val_score(reg, np.array(ds.YearsExperience).reshape(-1, 1), np.array(ds.Salary), cv = 10)
# Out:
# array([-0.38924082,  0.55149573, -1.50987515, -1.86521075,  0.25890956,
#        -0.96299211, -5.67146885, -0.06293342,  0.5165588 , -5.25496272])

# %%
import functools
sum = functools.reduce(lambda x,y: x+y, scores)
ave = sum/len(scores)
ave
# Out:
# -1.43897197175725
